# %%
import cv2
import pytesseract
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

custom_config = r'--oem 3 --psm 6'

def plot(img, title=None):
    plt.figure(figsize = (7,10))
    if title: plt.title(title)
    else: plt.title('Original Image')
    plt.axis(False)
    plt.imshow(img);

image = cv2.imread('/content/Seat Confirmation_page-0001.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plot(image)

text = pytesseract.image_to_string(image, config=custom_config)
print(text)
# Out:
# Receipt-Cum-Acknowledgement of Confirmation of Admission te First Year Under Graduate ]
# Technical Courses in Engineering and Technology (4 Years) & Mastéf of Engisecring-ent
# Technology (Integrated 5 Yéars) Admissions A.Y. 2022-23 tng
# Application ID :.EN22157598 Receipt No : 62824728 :
# Personal Details
# [Candidate Name|SHAIKH IRFAN AJMER PASHA :
# [| Genderfate SSC ate OF BARA B/BODS
# ‘andidature Type|Maharashtra - Type A Home University/Marathwada University
# [J categoryfopen SS *dCSSCSCSCSC Reg ory for Rmission|Open id
# Applied forews|yes 0 Applied for Orphan|No
# Person with Disabllity|
# [| __tinguistic Minority|Not Applicable =| ~——SSSSSS—«CReligious Minority|Religious Minority -Musiim |
# |____ Applied fortrwslves SS OOO—O—O—COC“‘;(SC;t””SCCSCSCSCSC‘“‘C‘*#@d
# [Admission Details
# | MeritNofaaase OO SCSCS™*C~CSCSeit Marks]9zn770n9S7
# [___ institute Name|6282 - All India Shri Shivaji Memorial Society's Institute of Information Technology,Pune |
# [__Course NamelArtificial Intelligence and Data Science
# EWS (Economically Weaker
# [Preference ofS Cd SCSC ate oF Amisslon|a/an/2022
# Exam Name Details
# |__ Name As Per HSC Result[SHAIKH IRFAN AJMER PASHA
# |______Name As Per MHTCET Result|SHAIKH TRFAN AJMER PASHA
# HT TREAM AIHER PASH
# Fee Amount| DD/Cheque | Payment wo | ee eee |
# | se. | Payment Mode ) Number Date Branch Name |
# Tos |_| auaw/2072 [Sid
# of Documents Submitted at Institute oe _ _
# seo. fo ocumentame
# | _1. _|Certificate of Indian Nationality in the Name of the Candidate.
# | 2. ‘Domicile Certificate of the Candidate showing his / her Domicile State is Maharashtra. |
# | Declaration of the Candidate for the respective Linguistic / Religious Minority Community in Proforma - 0 OR School rj
# | Leaving Certificate having information pertaining to Religion / Mother tongue. inated '
# |__4. _ [Eligibility Certificate for Economically Weaker Section In Proforma - V. oe |
# | _5. ___ [Statement of Marks or Certificate of Passing SSC / Equivalent Examination. | |
# } Statement of Marks or Certificate of Passing HSC / Equivalent Examination / Passing Marksheet/Certificate of 3 years |
# | Diploma in Engineering and Technology. } |
# | __7. __|Score Card of JEE Main (Paper - 1) 2022. t
# | _8.__—*(Score Card of MHT-CET 2022, CC—“‘“NNCC#C#COCO(‘(#dzS #«
# List of Documents Not Submitted at Institute Saas |
# peigerMos [Document Name et
# (5, —_(ineane Certificate of Parents issued by competent authority of Govt. Of Maharashtra having Annual Income upto Rs. 8
# Lacs. |
# Undertaking By Candidate |
# 1 hereby agree to confirm to rules, acts and laws enforced by Government from time to time. I hereby undertake that so long as I am !
# student of College / Institute, I will not behave in a manner which may result In compelling the authorities to take disciplinary action against me. 1)
# fully understand that the Principal / Director of College / Institute will have rights to expel, rusticate me from the institute, for any infringement of i
# the rules prescribed by the college / institute / university / government and the undertaking given above. I also herewith undertake that, at later! ‘
# stage, if it is found that | have submitted false certificate(s)/document(s), I am aware that my admission stands cancelled and fees paid by me will }
# Ine forfeited. Further I will be subjected to legal and/or penal action as per the provisions of the law. Ss |
# Place Date: 11/11 ]2) RED: |
# Waok— |
# ire of Candidate 1
# Printed On : 11/12/2022 1:23:11 PM (SHAIKH IRFAN AJMER PASHA) }
# Declaration by the College / Institute
# We hereby declare that, we are admitting this Candidate to our Institution for the academic year 2022-23 on verification of Candidate's|
# Identity and all the required documents mentioned. The candidate has paid the Fees mentioned in this receipt. We also declare that the admission of
# Candidate Is confirmed in presence of the Candidate.
# Printed By : 6282  aNNy SS
# rinted By fetes P @
# Reported By : 6282, 203,199.138.226:41789 oY, i —
# z/ 8861 /p; 3
# Reported On : 11/11/2022 1:23:02 PM X/ sisal of a tutor Name, Designation and Signature of the Issuing Officer i
# ti ON Py z 4
# NO) don Je }
# \ f 2g
# Op ne
# Som 302" 4
# =a came "4
# - oe i, a)
# & fen ieee, |
# QC scanned with OKEN Scanner

# %%
from pytesseract import Output

img = cv2.imread('images/bill.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
d = pytesseract.image_to_data(img, output_type=Output.DICT)
print(d.keys())
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-3107445.py in <cell line: 0>()
#       2
#       3 img = cv2.imread('images/bill.jpeg')
# ----> 4 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       5 d = pytesseract.image_to_data(img, output_type=Output.DICT)
#       6 print(d.keys())
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
n_boxes = len(d['text'])
for i in range(n_boxes):
    if int(d['conf'][i]) > 60:
        (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
        img = cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

plot(img)
